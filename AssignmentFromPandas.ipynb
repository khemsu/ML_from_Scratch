# %% [markdown]
# <a href="https://colab.research.google.com/github/khemsu/ML_from_Scratch/blob/main/AssignmentFromPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/Video_Games_Sales_as_at_22_Dec_2016.csv.zip")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# # **Projects**
#
#
# ---
#
#
# import nlibaries
# data load
# data structure
# first and last few rows of dataset
# examine datatypes
# null values
#
#
# *   identify null values
# *   count null values by column
# *   total null values in datasets
#
#
# ---
#
#
# -[Name,,Year_of_Release	,Genre,	Publisher,	Critic_Score,	Critic_Count,	User_Score,	User_Count,	Developer,	Rating] fill null values with a values 'Unknown'
#
#
# ---
#
#
# -Year_of_release convert it to int
#
#
# ---

# %% [markdown]
# FIrst few columns

# %%
df.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# First few last cloumns

# %%
df.tail(4)
# Out:
#                           Name Platform  Year_of_Release       Genre  \
# 16715         LMA Manager 2007     X360           2006.0      Sports
# 16716  Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717         Spirits & Spells      GBA           2003.0    Platform
# 16718      Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16715   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# ...

# %% [markdown]
# # **Data Structure**

# %%
df.shape
# Out:
# (16719, 16)

# %% [markdown]
# # Data types

# %%
df_null_types = df.isnull().any().dtypes
print(df_null_types)
# Out:
# bool

# %%
#changing year of release to int
x = df['Year_of_Release'].mean()
df['Year_of_Release'].fillna(x, inplace=True)
df['Year_of_Release'] = df['Year_of_Release'].astype(int)
df['Year_of_Release']. dtype
# Out:
# <ipython-input-11-2a277aa5b8fc>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Year_of_Release'].fillna(x, inplace=True)
# dtype('int64')

# %%
#identifying null values
isnull  = df.isnull()
print(isnull)
# Out:
#         Name  Platform  Year_of_Release  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False     False            False  False      False     False     False
# 1      False     False            False  False      False     False     False
# 2      False     False            False  False      False     False     False
# 3      False     False            False  False      False     False     False
# 4      False     False            False  False      False     False     False
# ...      ...       ...              ...    ...        ...       ...       ...
# 16714  False     False            False  False      False     False     False
# 16715  False     False            False  False      False     False     False
# 16716  False     False            False  False      False     False     False
# 16717  False     False            False  False      False     False     False
# 16718  False     False            False  False      False     False     False
#
# ...

# %%
#counting the null  by column
isnull_count= isnull.sum()
print("Total number of null are:\n",isnull_count)
# Out:
# Total number of null are:
#  Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
#total null values in datasets
# isnull vaneko null values ho ani tesko null le column wise null value dinxa ani tesko sum le total null value dinxa
isnull_sum = isnull.sum().sum()
print("Total number of null values are:\n",isnull_sum)
# Out:
# Total number of null values are:
#  49141

# %% [markdown]
# Fill Nan values in coulmns with Unknown

# %%
columns_to_fill = ["Name", "Year_of_Release", "Genre", "Publisher",
                   "Critic_Score", "Critic_Count", "User_Score",
                   "User_Count", "Developer", "Rating"]

df[columns_to_fill] = df[columns_to_fill].fillna("Unknown")
print(df)
# Out:
#           Name Platform Year_of_Release    Genre Publisher  NA_Sales  \
# 0      Unknown      Wii         Unknown  Unknown   Unknown     41.36
# 1      Unknown      NES         Unknown  Unknown   Unknown     29.08
# 2      Unknown      Wii         Unknown  Unknown   Unknown     15.68
# 3      Unknown      Wii         Unknown  Unknown   Unknown     15.61
# 4      Unknown       GB         Unknown  Unknown   Unknown     11.27
# ...        ...      ...             ...      ...       ...       ...
# 16714  Unknown      PS3         Unknown  Unknown   Unknown      0.00
# 16715  Unknown     X360         Unknown  Unknown   Unknown      0.00
# 16716  Unknown      PSV         Unknown  Unknown   Unknown      0.00
# 16717  Unknown      GBA         Unknown  Unknown   Unknown      0.01
# 16718  Unknown      PSV         Unknown  Unknown   Unknown      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales Critic_Score  \
# 0         28.96      3.77         8.45         82.53      Unknown
# ...

# %%
df_modified = df.to_csv("modified_dataset.csv", index=False)
print(df_modified)
# Out:
# None
